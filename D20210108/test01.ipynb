# %%
from PIL import Image
import matplotlib.pyplot as plt # plt 用于显示图片
import numpy as np
#cv2模板匹配   cv2.matchTemplate()
import cv2
img = Image.open('000004.jpg')
im=np.array(img)
print(im.shape)
# im.show()
plt.imshow(im)
# plt.axis('off') # 不显示坐标轴
plt.show()
height=img.size[0]
width=img.size[1]
list1=(width,height)
temp1=min(list1)
index=list1.index(temp1)
index
# Out:
# (37, 87, 3)
# 0

# %%
data=[]
for i in np.arange(1,1.5,0.05):
    temp2=temp1*i
    out = img.resize((temp1,round(temp2)),Image.ANTIALIAS) #resize image with high-quality
    img1=np.asarray(img)
    img2=np.asarray(out)
#     cor=cv2.matchTemplate(img2,img1,cv2.TM_CCORR_NORMED)
#     data.append(cor)
# data

# %%
img_temp=img.resize((temp1,round(temp1*1)),Image.ANTIALIAS)
im_temp=np.array(img_temp)
print(im_temp.shape)
# im.show()
plt.imshow(im_temp)
# Out:
# (37, 37, 3)

# %%
img.save('img.jpg')
img_temp.save('img_temp.jpg')

# %%
np.arange(1,2+0.05,0.05)
# Out:
# array([1.  , 1.05, 1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 ,
#        1.55, 1.6 , 1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  ])

# %%
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy as np

lena = mpimg.imread('000004.jpg') # 读取和代码处于同一目录下的 
# 此时 lena 就已经是一个 np.array 了，可以对它进行任意处理
lena.shape #(512, 512, 3)

plt.imshow(lena) # 显示图片
plt.axis('off') # 不显示坐标轴
# plt.show()
# Out:
# (-0.5, 86.5, 36.5, -0.5)
