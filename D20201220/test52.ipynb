# %%
import torch
from torch import nn
from torchvision import models
from torchvision import transforms as T
resnet34=models.resnet34(pretrained=True,num_classes=1000)
resnet34.fc=nn.Linear(512,10)

# %%
transform=T.Compose([
    T.Resize(224),
    T.CenterCrop(224),
    T.ToTensor(),
    T.Normalize(mean=[0.5,0.5,0.5],std=[0.5,0.5,0.5])
])

# %%
from torchvision import datasets
data=datasets.MNIST(
    root='./data/',
    download=False,
    train=False,
    transform=transform
)

# %%
from torchvision import transforms
import torch
to_pil=transforms.ToPILImage()
to_pil(torch.randn(3,64,64))
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7EBD49D5D0>

# %%
len(data)
# Out:
# 10000

# %%
from torch.utils.data import DataLoader
dataloader=DataLoader(data,shuffle=True,batch_size=16)
from torchvision.utils import make_grid,save_image
dataiter=iter(dataloader)
img=make_grid(next(dataiter)[0],4)
to_img(img)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-a4efcbd5c6ab> in <module>
#       3 from torchvision.utils import make_grid,save_image
#       4 dataiter=iter(dataloader)
# ----> 5 img=make_grid(next(dataiter)[0],4)
#       6 to_img(img)
#
# ~/anaconda3/envs/pytorch131/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     344     def __next__(self):
#     345         index = self._next_index()  # may raise StopIteration
# --> 346         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     347         if self._pin_memory:
#     348             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/envs/pytorch131/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/pytorch131/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/pytorch131/lib/python3.7/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      93
#      94         if self.transform is not None:
# ---> 95             img = self.transform(img)
#      96
#      97         if self.target_transform is not None:
#
# ~/anaconda3/envs/pytorch131/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      68     def __call__(self, img):
#      69         for t in self.transforms:
# ---> 70             img = t(img)
#      71         return img
#      72
#
# ~/anaconda3/envs/pytorch131/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, tensor)
#     173             Tensor: Normalized Tensor image.
#     174         """
# --> 175         return F.normalize(tensor, self.mean, self.std, self.inplace)
#     176
#     177     def __repr__(self):
#
# ~/anaconda3/envs/pytorch131/lib/python3.7/site-packages/torchvision/transforms/functional.py in normalize(tensor, mean, std, inplace)
#     215     mean = torch.as_tensor(mean, dtype=dtype, device=tensor.device)
#     216     std = torch.as_tensor(std, dtype=dtype, device=tensor.device)
# --> 217     tensor.sub_(mean[:, None, None]).div_(std[:, None, None])
#     218     return tensor
#     219
#
# RuntimeError: output with shape [1, 224, 224] doesn't match the broadcast shape [3, 224, 224]
